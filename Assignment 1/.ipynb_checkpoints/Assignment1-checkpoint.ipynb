# %% [markdown]
# **Name:** David Björelind
#
# **EID:** 40107147
#
# **Kaggle Team Name:** \_\_\_\_\_

# %% [markdown]
# # CS4487 - Assignment 1 - YouTube Spam Classifier

# %% [markdown]
# ## Goal
# In this assignment, the task is predict whether a comment about a YouTube video is spam or not.  Here are some examples of spam and not spam:
#   - **spam**: _"Huh, anyway check out this you[tube] channel: kobyoshi02"_
#   - **not spam**: _"Still watching this 2 years later?"_
#
# Your goal is to train a classifier to predict whether a comment is spam or not.
#
#
# ## Methodology
# You need to train classifiers using the training data, and then predict on the test data. You are free to choose the feature extraction method and classifier algorithm.  You are free to use methods that were not introduced in class.  You should probably do cross-validation to select a good parameters.
#
#
# ## Evaluation on Kaggle
#
# You need to submit your test predictions to Kaggle for evaluation.  A portion (~50%) of the test data will be used to show your ranking on the live leaderboard.  After the assignment deadline, the remaining portion will be used to calculate your final ranking. The entry with the highest final ranking will win a prize!  Also the top-ranked entries will be asked to give a short 5 minute presentation on what they did.
#
# To submit to Kaggle you need to create an account, and use the competition invitation that will be posted on Canvas.
#
# **Note:** You can only submit 2 times per day to Kaggle!
#
# ## What to hand in
# You need to turn in the following things:
#
# 1. This ipynb file `Assignment1.ipynb`, containing your source code and documentation. _**You should write about all the various attempts that you make to find a good solution.**_
# 2. Your final submission file to Kaggle.
# 3. The ipynb file `Assignment1-Final.ipynb`, which contains the code that generates the final submission file that you submit to Kaggle.  **This code will be used to verify that your Kaggle submission is reproducible.**
#
# Files should be uploaded to Assignment 1 on Canvas.
#
# ## Grading
# The marks of the assignment are distributed as follows:
# - 40% - Results using various classifiers and feature representations.
# - 20% - Trying out feature representations (e.g. adding additional features) or classifiers not used in the tutorials.
# - 20% - Quality of the written report.  More points for insightful observations and analysis.
# - 20% - Final ranking on the Kaggle test data (private leaderboard). If a submission cannot be reproduced by the submitted code, it will not receive marks for ranking.
# - **Late Penalty:** 25 marks will be subtracted for each day late.
#
# **Note:** you should start early! Some classifiers may take a while to train.
# <hr>

# %% [markdown]
# # Load the Data

# %% [markdown]
# The training data is in the text file `youtube_spam_train.csv`.  This CSV file contains the comment text, comment author names, date, video IDs, and classes. The class labels are: `0` for "not spam", and `1` for "spam".
#
# The testing data is in the text file `youtube_spam_test.csv`, and includes everything except the class labels.
#
# Note that the data is in chronological order -- the dates of the training data precede the dates of the test data.  This is to make the experiment more like a real situation, where we collect data up to a certain time to train the models, and then test on the new incoming data.
#
# Besides the comment text, you can also use the author names, video names, or dates to build your classifier.
#
# To submit to Kaggle, you need to generate a Kaggle submission files, which is CSV file with the following format:
#
# <pre>
# Id,Prediction
# 1,0
# 2,1
# 3,1
# 4,0
# ...
# </pre>

# %% [markdown]
# Here are some helpful code to get you started reading the data and writing the Kaggle submission file.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
from scipy import stats
random.seed(100)
import csv
import pandas as pd

# a function for plotting the word probabilities
def plotWordProb(model):
    xr = arange(0,len(cntvect.vocabulary_))
    plt.figure(figsize=(8,3))
    plt.bar(xr, exp(model.feature_log_prob_[0,:]), width=0.4, label= "0")
    plt.bar(xr+0.5, exp(model.feature_log_prob_[1,:]), width=0.4, color='r', label= "1")
    plt.legend()
    plt.xlabel('word index'); plt.ylabel('probability $p(x_j=1|y)$');
    plt.xlim(min(xr), max(xr)+1)

# %%
# function to write a CSV file for Kaggle submission
def write_csv_kaggle_sub(fname, Y):
    # fname = file name
    # Y is a list/array with class entries
    with open(fname, 'w') as f:
        writer = csv.writer(f)

        # header
        tmp = ['Id', 'Prediction']            
        writer.writerow(tmp)
    
        # add ID numbers for each Y, and usage if necessary
        for (i,y) in enumerate(Y):
            tmp2 = [(i+1), y]
            writer.writerow(tmp2)
        
        f.close()

# %% [markdown]
# The below code will load the training and test sets.

# %%
# load the data with pandas
traindf = pd.read_csv('youtube_spam_train.csv')
testdf  = pd.read_csv('youtube_spam_test.csv')

# extract data into a dictionary

train = {}                                 ### training data
train['txt']   = list(traindf['TEXT'])     # comment text
train['class'] = list(traindf['CLASS'])    # class (0=not spam; 1=spam)
train['author'] = list(traindf['AUTHOR'])  # author name
train['video']  = list(traindf['VIDEO'])   # video ID
train['date']   = list(traindf['DATE'])    # date of the comment

test = {}                                  ### testing data
test['txt']   = list(testdf['TEXT'])
test['author'] = list(testdf['AUTHOR'])
test['video']  = list(testdf['VIDEO'])
test['date']    = list(testdf['DATE'])

print(len(train['txt']))
print(len(test['txt']))
# Out:
# 1000
# 956

# %% [markdown]
# Here is an example to write a csv file with some predictions on the test set.

# %%
# write your predictions on the test set
predY = zeros(len(test['txt'])) # for example, predict all 0
write_csv_kaggle_sub("my_submission.csv", predY)

# %% [markdown]
# Look at the first 10 samples in the training data:

# %%
for t in range(200):
    print("=== Class={}, Video={}, Author={}, Date={}".format( 
        train['class'][t], train['video'][t], 
        train['author'][t], train['date'][t]))
    print(train['txt'][t])
# Out:
# === Class=0, Video=pRpeEdMmmQ0, Author=Latin Bosch, Date=2013-07-12T22:33:27.916000
# Shakira is the best dancer
# === Class=0, Video=pRpeEdMmmQ0, Author=Aishlin Maciel, Date=2013-07-13T11:17:52.308000
# Shakira u are so wiredo
# === Class=0, Video=pRpeEdMmmQ0, Author=jeffrey jules, Date=2013-07-13T12:09:31.188000
# wow
# === Class=0, Video=pRpeEdMmmQ0, Author=Sabina Pearson-Smith, Date=2013-07-13T13:14:30.021000
# I love this song for two reasons: 1.it is about Africa 2.i was born in beautiful south Africa
# === Class=0, Video=pRpeEdMmmQ0, Author=Katie Mettam, Date=2013-07-13T13:27:39.441000
# I love this song because we sing it at Camp all the time!!
# === Class=0, Video=pRpeEdMmmQ0, Author=Dinova Sharon, Date=2013-07-13T14:44:00.700000
# well done shakira
# === Class=0, Video=pRpeEdMmmQ0, Author=TheHotChocolate, Date=2013-07-13T18:26:37.017000
# she is sooooo beautiful!
# === Class=0, Video=pRpeEdMmmQ0, Author=Ysobel Schofield, Date=2013-07-13T20:17:25.181000
# Waka waka she rules
# === Class=1, Video=pRpeEdMmmQ0, Author=ThirdDegr3e, Date=2013-07-13T20:47:40.793000
# **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAP
# === Class=0, Video=pRpeEdMmmQ0, Author=jack nons, Date=2013-10-04T02:35:47.067000
# I love it
# === Class=0, Video=pRpeEdMmmQ0, Author=ranferi delgado, Date=2013-10-04T03:56:04.784000
# best song eva
# === Class=0, Video=pRpeEdMmmQ0, Author=mermskg, Date=2013-10-04T05:20:55.524000
# This makes me miss the world cup
# === Class=0, Video=pRpeEdMmmQ0, Author=Tydings Jay, Date=2013-10-04T07:47:56.333000
# Waka waka
# === Class=0, Video=pRpeEdMmmQ0, Author=Directioner For Life, Date=2013-10-04T13:54:20.918000
# I remember this :D
# === Class=0, Video=pRpeEdMmmQ0, Author=5000palo, Date=2013-10-04T14:21:59.312000
# Shakira :-*
# === Class=0, Video=pRpeEdMmmQ0, Author=Alain Bruno, Date=2013-10-04T14:24:49.500000
# Shakira is perfect
# === Class=0, Video=pRpeEdMmmQ0, Author=5000palo, Date=2013-10-04T16:15:05.278000
# I want new song
# === Class=0, Video=pRpeEdMmmQ0, Author=Aliens Studios, Date=2013-10-04T17:13:18.472000
# like!!!!!
# === Class=0, Video=pRpeEdMmmQ0, Author=Odín000, Date=2013-10-04T17:15:51.850000
# Where are Shakifans?
# === Class=0, Video=pRpeEdMmmQ0, Author=WhipCreamOnTop, Date=2013-10-04T18:46:53.897000
# this song is racist
# === Class=0, Video=pRpeEdMmmQ0, Author=Capo Crimini, Date=2013-10-04T18:59:40.338000
# Your a fucking bitch
# === Class=1, Video=pRpeEdMmmQ0, Author=emoclew71, Date=2013-10-04T19:18:44.700000
# 1 753 682 421 GANGNAM STYLE ^^
# === Class=0, Video=pRpeEdMmmQ0, Author=5000palo, Date=2013-10-04T19:40:44.339000
# She is perfect
# === Class=0, Video=pRpeEdMmmQ0, Author=Masreya .., Date=2013-10-04T22:38:44.441000
# I like
# === Class=0, Video=pRpeEdMmmQ0, Author=Gabriella Korotasz, Date=2013-10-04T22:49:59.635000
# She&#39;s so pretty
# === Class=0, Video=pRpeEdMmmQ0, Author=tyler sleetway, Date=2013-10-05T00:57:25.078000
# so beutiful
# === Class=0, Video=pRpeEdMmmQ0, Author=tyler sleetway, Date=2013-10-05T00:57:25.078000
# so beutiful
# === Class=1, Video=pRpeEdMmmQ0, Author=Su Xianfeng, Date=2013-10-05T11:54:10.192000
# subscribe now!!!!!! love the song!!!!!! love football!!!
# === Class=1, Video=pRpeEdMmmQ0, Author=Hadrien Robalo Marques, Date=2013-10-05T22:31:44.181000
# The britishs called that soccer but you know the true word is football and the US Foot is called rugby. That works like that in EUW ( Germany/ Netherland/ France/ Portugal/ Belgium/ Spain/ ... ) Just because the Britishs don&#39;t agree to be like us because they are UNIQUE. That&#39;s the reason why they also refused to have euro (€) as money
# === Class=1, Video=pRpeEdMmmQ0, Author=WhatUKnow, Date=2013-10-06T03:24:16.073000
# Subscribe to my channel :)  &lt;3
# === Class=1, Video=pRpeEdMmmQ0, Author=jameskileymusic, Date=2013-10-06T05:38:47.524000
# Check out my bass cover of hips don&#39;t lie by shakira!
# === Class=1, Video=pRpeEdMmmQ0, Author=WhatUKnow, Date=2013-10-07T02:59:17.497000
# === Class=1, Video=pRpeEdMmmQ0, Author=prem kumar, Date=2013-11-03T11:15:28.071000
# Hi there, have you heard about DribbleProShot? Just do a search on Google. On their web site you can watch a smart free video featuring the best way to significantly boost your football aka soccer skills in no time... It turned Nick into a much better football or soccer player...His team mates were definitily amazed! I hope it will help you also...
# === Class=1, Video=pRpeEdMmmQ0, Author=AllDailyVines, Date=2013-11-03T12:11:52.335000
# hahahahah ♥♥♥♥ :D like vines ?  Subscribe to me for daily vines
# === Class=1, Video=pRpeEdMmmQ0, Author=mile panika, Date=2013-11-03T14:39:42.248000
# I absolutely adore watching football plus I’ve started earning income with out risk from claiming bonus deals. It’s a weird technique where you put money on something with one bookmakers and put money against it on Betfair. You acquire the bonus as income . A lad named Jim Vanstone is selecting the wagers free on his website Vanstone Secrets (Google it!). I have generated about 600 quid so far. And it’s free. I assume the bookmakers pay him to get new men and women, but it succeeds.
# === Class=1, Video=pRpeEdMmmQ0, Author=angela pollman, Date=2013-11-04T01:38:02.979000
# and how many subscribers compared to her over a million
# === Class=1, Video=pRpeEdMmmQ0, Author=Ali Reza Nipu, Date=2013-11-05T06:23:41.092000
# I really love watching football and also I’ve started off making income with out financial risk from acquiring bonus deals. It’s this weird technique where you wager on something with one bookmakers and bet against it on Betfair. You secure the bonus as income . A chap named Jim Vanstone is finding the wagers free on his own website Vanstone Secrets (Google it!). I’ve made about 500 quid thus far. And it is cost-free. I guess the bookies pay him to obtain new consumers, yet this actually works.

# %% [markdown]
# # YOUR CODE and DOCUMENTATION HERE

# %%
### Looking at some more examples of spam comments

inds = []

for i in range(50):
    if train['class'][i] == 1:
        inds.append(i)

for t in inds:
    print("=== Class={}, Video={}, Author={}, Date={}".format( 
        train['class'][t], train['video'][t], 
        train['author'][t], train['date'][t]))
    print(train['txt'][t])
# Out:
# === Class=1, Video=pRpeEdMmmQ0, Author=ThirdDegr3e, Date=2013-07-13T20:47:40.793000
# **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE****
# === Class=1, Video=pRpeEdMmmQ0, Author=ThirdDegr3e, Date=2013-07-13T20:48:06.033000
# **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE****
# === Class=1, Video=pRpeEdMmmQ0, Author=ThirdDegr3e, Date=2013-07-13T20:48:22.967000
# **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE****
# === Class=1, Video=pRpeEdMmmQ0, Author=Shadrach Grentz, Date=2013-07-14T03:11:20.243000
# Hey Music Fans I really appreciate all of you who take time to read this, and check my music out! I&#39;m just a 15 year old boy DREAMING of being a successful MUSICIAN in the music world. I do lots of covers, and piano covers. But I dont have money to advertise. A simple thumbs up to my comment, a comment on my videos or a SUBSCRIPTION would be a step forward! It will only be a few seconds of your life that u won&#39;t regret!!! Thank u to all the people who just give me a chance it means a lot! :)
# === Class=1, Video=pRpeEdMmmQ0, Author=ricky swaggz, Date=2013-07-14T20:40:00.331000
# ********OMG Facebook is OLD! Check out  -----------------&gt; swagFriends com Make thousands of cool new friends everyday! Join the movement!
# === Class=1, Video=pRpeEdMmmQ0, Author=FAHAD KHAN, Date=2013-07-14T22:06:57.712000
# I WILL NEVER FORGET THIS SONG IN MY LIFE LIKE THIS COMMENT OF YOUR HEARING THIS SONG FOR LIKE A YEAR!!!!!
# === Class=1, Video=pRpeEdMmmQ0, Author
# Please.. Check my channel out:) I subscribe back..;)
# === Class=1, Video=pRpeEdMmmQ0, Author=Titan, Date=2013-08-08T21:15:36.040000
# Subscribe me, I will? subscribe you back!!!
# === Class=1, Video=pRpeEdMmmQ0, Author=Titan, Date=2013-08-08T21:16:25.626000
# Subscribe me, I will? subscribe you back!!!

# %%
### Due to the simularity with Tutorial 2, I will start by making a vocabulary from the training data

stopwords = ['english', 'll', 'of']
cntvect = feature_extraction.text.CountVectorizer(stop_words = stopwords, max_features=100)

trainX = cntvect.fit_transform(train['txt'])
trainY = train['class']

# calculate vectors for the test data
testX  = cntvect.transform(test['txt'])

### Making it pretty to print the vocab

def showVocab(vocab, counts=None):
    "print out the vocabulary. if counts specified, then only print the words w/ non-zero entries"
    allwords = list(vocab.keys())
    allwords.sort()  # sort vocabulary by index
    wordlist = []
    for word in allwords:
        ind = vocab[word]
        if (counts is None):
            mystr = "{:3d}. {}".format(ind, word)
        elif (counts[0,ind]>0):
            mystr = "{:3d}. ({:0.4f}) {}".format(ind, counts[0,ind], word)
        else:
            continue  # skip it
        wordlist.append(mystr)

    # print 2 columns
    it = iter(wordlist)
    for i in it:
        print('{:<30}{}'.format(i, next(it)))
            
# show the vocabulary
showVocab(cntvect.vocabulary_)
# Out:
#   0. 39                         1. all
#   2. am                         3. amp
#   4. and                        5. are
#   6. as                         7. at
#   8. be                         9. because
#  10. best                      11. billion
#  12. br                        13. but
#  14. by                        15. can
#  16. channel                   17. check
#  18. com                       19. comment
#  20. do                        21. don
#  22. everyone                  23. facebook
#  24. for                       25. free
#  26. from                      27. get
#  28. go                        29. good
#  30. guys                      31. has
#  32. have                      33. help
#  34. her                       35. hey
#  36. how                       37. http
#  38. https                     39. if
#  40. in                        41. is
#  42. it                        43. just
#  44. katy                      45. know
#  46. like                      47. love
#  48. lt                        49. make
#  50. me                        51. mixtape
#  52. money                     53. much
#  54. music                     55. my
#  56. new                       57. no
#  58. not                       59. now
#  60. on                        61. one
#  62. only                      63. or
#  64. our                       65. out
#  66. people                    67. perry
#  68. please                    69. quot
#  70. really                    71. see
#  72. she                       73. so
#  74. song                      75. subscribe
#  76. thank                     77. thanks
#  78. that                      79. the
#  80. there                     81. this
#  82. time                      83. to
#  84. up                        85. us
#  86. video                     87. videos
#  88. views                     89. watch
#  90. we                        91. who
#  92. will                      93. with
#  94. world                     95. would
#  96. www                       97. you
#  98. your                      99. youtube

# %%
### Fit the NB Bernoulli model w/ smoothing do the data since it had the highest accuracy last time

firstModel = naive_bayes.BernoulliNB(alpha=0)
firstModel.fit(trainX, trainY)
# Out:
# /Users/davidbjorelind/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# BernoulliNB(alpha=0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# Making a plot in order to evaluate the value of Alpha
plotWordProb(firstModel)
plt.title('probability of word present (with smoothing)');

# %% [raw]
# # When playing around with different values of alpha, I see that it doesn't really has a big effect on
# the probabilities of the different words. Therefore, I am continuing with a rather small value for Alpha
